# %%
from eda_df_class_1 import EDAdf

# %%
num_cols = ['GarageYrBlt', '1stFlrSF', 'BsmtFinSF1',
            'TotRmsAbvGrd', 'OpenPorchSF', 'GarageCars', 'GrLivArea', '2ndFlrSF', 'TotalBsmtSF', 'SalePrice']

eda_df_class = EDAdf('../data/train.csv', num_cols)

eda_df_class.display()
# Out:
#      LandContour  GarageYrBlt  FullBath  1stFlrSF  BsmtFinSF1  TotRmsAbvGrd  \
# 0            Lvl       2003.0         2       856         706             8
# 1            Lvl       1976.0         2      1262         978             6
# 2            Lvl       2001.0         2       920         486             6
# 3            Lvl       1998.0         1       961         216             7
# 4            Lvl       2000.0         2      1145         655             9
# ...          ...          ...       ...       ...         ...           ...
# 1455         Lvl       1999.0         2       953           0             7
# 1456         Lvl       1978.0         2      2073         790             7
# 1457         Lvl       1941.0         2      1188         275             9
# 1458         Lvl       1950.0         1      1078          49             5
# 1459         Lvl       1965.0         1      1256         830             6
#
# ...

# %%
eda_df_class.show_missing_values()

# We need to do something with missing values during teaching

# %%
eda_df_class.visualize_box_and_hist_plots()

# I don't see any outliers

# %%
eda_df_class.visualize_bar_plots()
