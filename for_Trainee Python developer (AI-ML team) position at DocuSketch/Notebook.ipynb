# %%
'''1.Create project in idea, pycharm or vscode'''
# Out:
# '1.Create project in idea, pycharm or vscode'

# %%
'''2.Create class for drawing plots'''
import plots # my class

# %%
plots_class = plots.Plots('https://ai-process-sandy.s3.eu-west-1.amazonaws.com/purge/deviation.json', 'plots')

# %%
plots_class.display_df()
# Out:
#                   name  gt_corners  rb_corners       mean        max  \
# 0         Schlafzimmer           4           4   3.956313   8.562939
# 1                Küche           4           4  23.019122  52.605437
# 2             Bathroom           4           4   1.013833   1.950322
# 3         Lounge/Diner           8           8   3.832620  18.236935
# 4           Essbereich           4           4   8.017758  15.642853
# ...                ...         ...         ...        ...        ...
# 1342    Master Bedroom           4           4   1.739907   4.703960
# 1343  Master Bedroom 2           4           4   0.530908   0.786997
# 1344          Zimmer I           4           4   0.880569   1.221873
# 1345  Hallway Bathroom           6           6  24.923452  64.266820
# 1346         Bedroom 4           4           4   0.387328   0.762659
#
#            min  floor_mean  floor_max  floor_min  ceiling_mean  ceiling_max  \
# ...

# %%
'''MAIN TASK: Please create meaningful statistics of how well the model performed.'''

plots_class.draw_conf_mat_plot(need_to_save_file=True)

# I think this plot is the most important. With this plot we can make some suggestions.

# 1. It looks like the model over-fitted here. All predictions are true, and it's not good :(
# 2. We have only 1 value for 10 corners. I can't even imagine how this room looks like :)

# %%
plots_class.draw_amount_room_plot(need_to_save_file=True)

# I just wanted to check what the most popular rooms are. The most popular room is "Master Bedroom"

# %%
plots_class.draw_distribution_plots()

# I can't see any outliers here in distribution

# %%
plots_class.draw_mean_and_corr_plot()

# I can see if there are more corners it looks like more mean
# Out:
# correlation: 0.1307528215282328

# %%
'''3.Create function “draw_plots”
→ reads json file passed as parameter as a pandas dataframe
→ draws plot for comparing different columns
→ saves plots in a folder called “plots”
→ returns paths to all plots'''

print(plots_class.get_paths())

plots_class.draw_plots()
# Out:
# {WindowsPath('plots/amount_rooms_in_every_type.png'), WindowsPath('plots/heatmap_confusion_matrix.png')}
# ____________________________________________________________________________________________________
# ____________________________________________________________________________________________________
# ____________________________________________________________________________________________________
# correlation: 0.1307528215282328

# %%
'''
4.Create jupyter notebook called Notebook.ipynb in the root directory to call and visualize our
plots
5.Publish the project on github
'''
# Out:
# '\n4.Create jupyter notebook called Notebook.ipynb in the root directory to call and visualize our\nplots\n5.Publish the project on github\n'
